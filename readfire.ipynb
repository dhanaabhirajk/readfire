# %% [markdown]
# <a href="https://colab.research.google.com/github/dhanaabhirajk/readfire/blob/master/readfire.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pip install firebase-admin

# %%
import firebase_admin
from firebase_admin import credentials,firestore

#connecting to db
cred = credentials.Certificate("./ServiceAccountKey.json")
default_app = firebase_admin.initialize_app(cred)
db = firestore.client()

# %%
#pip freeze > requirements.txt

# %%
import nltk
#used to remove stop words
nltk.download('stopwords')
#used in word tokenize
nltk.download('punkt')

from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# ##Prepocessing

# %%
import unicodedata #to convert the sentence to unicode
import re #used to remove punctuations


#Converting unicode to ascii 
def unicode_to_ascii(s):
    return ''.join(c for c in unicodedata.normalize('NFD', s) if unicodedata.category(c) != 'Mn')
    
def preprocess(w):
  #lowercase all the text
  w = unicode_to_ascii(w.lower().strip())

  #Remove puntuations
  w = re.sub(r"([?.!,¿])", r" ", w)
  w = re.sub(r'[" "]+', " ", w)
  w = re.sub(r"[^a-zA-Z?.!,¿]+", " ", w)

  #tokenizes into words
  word_tokens = word_tokenize(w)
  
  #remove stopwords
  new_sent = [w for w in word_tokens if w not in stop_words]
  
  #join the words
  new_sent = ' '.join(str(elem) for elem in new_sent)
  
  return new_sent

# %%
import pandas as pd
import numpy as np
import heapq

# %%
# function to return the dataframe with the preprocessed articles
def get_articles():
  articles = pd.DataFrame()
  for doc in docs:
    new_dic = doc.to_dict()
    articles = articles.append({"title":new_dic["title"],"id":doc.id,"content":preprocess(new_dic["content"]),"similar_id":list(),"similar_per":list()},ignore_index=True)
  return articles

# %%
#getting the docs from the database
docs = db.collection(u'articles').stream()

#get the preprocessed articles
articles = get_articles()

# %%
articles.head()
# Out:
#                                 title                    id  \
# 0                             Bio gas  G2q76a8fpjzXg3PAaGLi
# 1  Natural language processing (NLP)   L1oTvamoCndM7wLYvQ4S
# 2                     Web Development  MAVau2RZpWtDwC9YkpoH
# 3                  process scheduling  Y4RYcntx6PUpP9uMAoBZ
# 4                    Hybrid Vechicle   aT99AvBvVW43U1bEXn9p
#
#                                              content similar_id similar_per
# 0  biogas mixture gases primarily consisting meth...         []          []
# 1  natural language processing nlp refers branch ...         []          []
# 2  web development work involved developing websi...         []          []
# 3  process scheduling activity process manager ha...         []          []
# 4  hybrid electric vehicles powered internal comb...         []          []

# %% [markdown]
# ##Finding similarity with word2vec techniques

# %%
#similarity threshold value for unique words technique
threshold_value = 0.4

# %%
def visualize_similarity(similarities):
  # Visualizing the similarityby turning into a dataframe 
  return pd.DataFrame(similarities,
             index=articles["title"],
             columns=articles["title"]) \
            .style \
            .background_gradient(axis=None)

# %%
def add_similarity(similarities):
  length = len(articles)
  for i in range(length):
    articles.iloc[i]["similar_per"]=[]
    articles.iloc[i]["similar_id"]=[]
    for j in range(length):
      #condition to append the articles with similarity above threshold value
      if(i!=j and similarities[i][j]>threshold_value):
        #round of the value to 3 decimal points
        articles.iloc[i]["similar_per"].append(round(similarities[i][j],3))
        articles.iloc[i]["similar_id"].append(articles.iloc[j]["id"])

# %%
def update_article_similarity():
  for index in range(len(articles)):
    related = list()
    #atmost top 3 related articles
    larg3 = heapq.nlargest(3, zip( articles['similar_per'][index] , articles['similar_id'][index]))
    for i in larg3:
      related.append({"id":i[1],"per":i[0]})
    db.collection(u"articles").document(articles['id'][index]).update({"related":related})

# %% [markdown]
# ##Finding Similarity with unique words technique

# %% [markdown]
# ##Tokenizing and storing the vocubulary

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer(num_words=10000, oov_token='<UNK>')

tokenizer.fit_on_texts(articles["content"])

# %%
maxlen = 100

from tensorflow.keras.preprocessing.sequence import pad_sequences

#A function to return padded article
def get_sequences(article):
  sequences = tokenizer.texts_to_sequences([article])
  padded = pad_sequences(sequences, truncating='post', padding='post', maxlen=maxlen)
  return padded[0]

# %%
#stores the articles in vectors
vectors = [get_sequences(article) for article in articles["content"] ]

# %%
#Generating the similarity between the articles using pairwise cosine similarity 

similarities = cosine_similarity(vectors).astype('float64') #firestore needs data in float64
visualize_similarity(similarities)
# Out:
# <style type="text/css">
# #T_79433_row0_col0, #T_79433_row1_col1, #T_79433_row2_col2, #T_79433_row3_col3, #T_79433_row4_col4, #T_79433_row5_col5, #T_79433_row6_col6 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_79433_row0_col1, #T_79433_row1_col0 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_79433_row0_col2, #T_79433_row2_col0 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_79433_row0_col3, #T_79433_row1_col4, #T_79433_row3_col0, #T_79433_row4_col1 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_79433_row0_col4, #T_79433_row4_col0 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_79433_row0_col5, #T_79433_row5_col0 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_79433_row0_col6, #T_79433_row6_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_79433_row1_col2, #T_79433_row2_col1 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_79433_row1_col3, #T_79433_row3_col1 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_79433_row1_col5, #T_79433_row5_col1 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_79433_row1_col6, #T_79433_row6_col1 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_79433_row2_col3, #T_79433_row3_col2 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_79433_row2_col4, #T_79433_row4_col2 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_79433_row2_col5, #T_79433_row5_col2 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_79433_row2_col6, #T_79433_row6_col2 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_79433_row3_col4, #T_79433_row4_col3 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_79433_row3_col5, #T_79433_row5_col3 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_79433_row3_col6, #T_79433_row6_col3 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_79433_row4_col5, #T_79433_row5_col4 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_79433_row4_col6, #T_79433_row6_col4 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_79433_row5_col6, #T_79433_row6_col5 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# </style>
# <table id="T_79433_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >title</th>
#       <th class="col_heading level0 col0" >Bio gas</th>
#       <th class="col_heading level0 col1" >Natural language processing (NLP) </th>
#       <th class="col_heading level0 col2" >Web Development</th>
#       <th class="col_heading level0 col3" >process scheduling</th>
#       <th class="col_heading level0 col4" >Hybrid Vechicle </th>
#       <th class="col_heading level0 col5" >Gobar Gas</th>
#       <th class="col_heading level0 col6" >Artificial Intelligence</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >title</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79433_level0_row0" class="row_heading level0 row0" >Bio gas</th>
#       <td id="T_79433_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_79433_row0_col1" class="data row0 col1" >0.332942</td>
#       <td id="T_79433_row0_col2" class="data row0 col2" >0.543996</td>
#       <td id="T_79433_row0_col3" class="data row0 col3" >0.426816</td>
#       <td id="T_79433_row0_col4" class="data row0 col4" >0.518778</td>
#       <td id="T_79433_row0_col5" class="data row0 col5" >0.612573</td>
#       <td id="T_79433_row0_col6" class="data row0 col6" >0.232432</td>
#     </tr>
#     <tr>
#       <th id="T_79433_level0_row1" class="row_heading level0 row1" >Natural language processing (NLP) </th>
#       <td id="T_79433_row1_col0" class="data row1 col0" >0.332942</td>
#       <td id="T_79433_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T
row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##Spacy

# %%
#downloading module from spacy
# !python -m spacy download en_core_web_md
# Out:
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_md==2.2.5) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_md==2.2.5) (1.24.3)
# Building wheels for collected packages: en-core-web-md
#   Building wheel for en-core-web-md (setup.py) ... done
#   Created wheel for en-core-web-md: filename=en_core_web_md-2.2.5-py3-none-any.whl size=98051301 sha256=680ee05c8c380be6934e16b1e9f61fcd4afbd6ecc468bf3667ee76eeebb8a7b0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hsfoqaqy/wheels/69/c5/b8/4f1c029d89238734311b3269762ab2ee325a42da2ce8edb997
# Successfully built en-core-web-md
# Installing collected packages: en-core-web-md
# Successfully installed en-core-web-md-2.2.5
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_md')

# %%
#loading the smodel
import en_core_web_md
nlp = en_core_web_md.load()

# %%
#finding the vector for each article based on word embedding
vectors = [nlp(article).vector for article in articles["content"] ]

# %%
similarities = cosine_similarity(vectors).astype('float64')
visualize_similarity(similarities)
# Out:
# <style type="text/css">
# #T_f16d5_row0_col0, #T_f16d5_row1_col1, #T_f16d5_row2_col2, #T_f16d5_row3_col3, #T_f16d5_row4_col4, #T_f16d5_row5_col5, #T_f16d5_row6_col6 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_f16d5_row0_col1, #T_f16d5_row1_col0 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_f16d5_row0_col2, #T_f16d5_row2_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_f16d5_row0_col3, #T_f16d5_row3_col0 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_f16d5_row0_col4, #T_f16d5_row4_col0 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_f16d5_row0_col5, #T_f16d5_row5_col0 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_f16d5_row0_col6, #T_f16d5_row6_col0 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_f16d5_row1_col2, #T_f16d5_row2_col1 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_f16d5_row1_col3, #T_f16d5_row3_col1 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_f16d5_row1_col4, #T_f16d5_row2_col4, #T_f16d5_row4_col1, #T_f16d5_row4_col2 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_f16d5_row1_col5, #T_f16d5_row5_col1 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_f16d5_row1_col6, #T_f16d5_row6_col1 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_f16d5_row2_col3, #T_f16d5_row3_col2 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_f16d5_row2_col5, #T_f16d5_row5_col2 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_f16d5_row2_col6, #T_f16d5_row6_col2 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_f16d5_row3_col4, #T_f16d5_row4_col3 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_f16d5_row3_col5, #T_f16d5_row5_col3 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_f16d5_row3_col6, #T_f16d5_row6_col3 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_f16d5_row4_col5, #T_f16d5_row5_col4 {
#   background-color: #4897c4;
#   color: #f1f1f1;
# }
# #T_f16d5_row4_col6, #T_f16d5_row6_col4 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_f16d5_row5_col6, #T_f16d5_row6_col5 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# </style>
# <table id="T_f16d5_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >title</th>
#       <th class="col_heading level0 col0" >Bio gas</th>
#       <th class="col_heading level0 col1" >Natural language processing (NLP) </th>
#       <th class="col_heading level0 col2" >Web Development</th>
#       <th class="col_heading level0 col3" >process scheduling</th>
#       <th class="col_heading level0 col4" >Hybrid Vechicle </th>
#       <th class="col_heading level0 col5" >Gobar Gas</th>
#       <th class="col_heading level0 col6" >Artificial Intelligence</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >title</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_
row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_f16d5_row5_col6" class="data row5 col6" >0.717275</td>
#     </tr>
#     <tr>
#       <th id="T_f16d5_level0_row6" class="row_heading level0 row6" >Artificial Intelligence</th>
#       <td id="T_f16d5_row6_col0" class="data row6 col0" >0.687438</td>
#       <td id="T_f16d5_row6_col1" class="data row6 col1" >0.896673</td>
#       <td id="T_f16d5_row6_col2" class="data row6 col2" >0.814347</td>
#       <td id="T_f16d5_row6_col3" class="data row6 col3" >0.842014</td>
#       <td id="T_f16d5_row6_col4" class="data row6 col4" >0.695665</td>
#       <td id="T_f16d5_row6_col5" class="data row6 col5" >0.717275</td>
#       <td id="T_f16d5_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#adding the similarity to the dataframe
add_similarity(similarities)
articles.head()
# Out:
#                                 title                    id  \
# 0                             Bio gas  G2q76a8fpjzXg3PAaGLi
# 1  Natural language processing (NLP)   L1oTvamoCndM7wLYvQ4S
# 2                     Web Development  MAVau2RZpWtDwC9YkpoH
# 3                  process scheduling  Y4RYcntx6PUpP9uMAoBZ
# 4                    Hybrid Vechicle   aT99AvBvVW43U1bEXn9p
#
#                                              content  \
# 0  biogas mixture gases primarily consisting meth...
# 1  natural language processing nlp refers branch ...
# 2  web development work involved developing websi...
# 3  process scheduling activity process manager ha...
# 4  hybrid electric vehicles powered internal comb...
#
#                                           similar_id  \
# 0  [L1oTvamoCndM7wLYvQ4S, MAVau2RZpWtDwC9YkpoH, Y...
# 1  [G2q76a8fpjzXg3PAaGLi, MAVau2RZpWtDwC9YkpoH, Y...
# 2  [G2q76a8fpjzXg3PAaGLi, L1oTvamoCndM7wLYvQ4S, Y...
# 3  [G2q76a8fpjzXg3PAaGLi, L1oTvamoCndM7wLYvQ4S, M...
# 4  [G2q76a8fpjzXg3PAaGLi, L1oTvamoCndM7wLYvQ4S, M...
#
#                                   similar_per
# 0   [0.654, 0.609, 0.71, 0.821, 0.985, 0.687]
# 1  [0.654, 0.765, 0.769, 0.641, 0.698, 0.897]
# 2  [0.609, 0.765, 0.817, 0.642, 0.659, 0.814]
# 3   [0.71, 0.769, 0.817, 0.751, 0.747, 0.842]
# 4  [0.821, 0.641, 0.642, 0.751, 0.839, 0.696]

# %%
# updating the article similarity in the database
update_article_similarity()

# %% [markdown]
# ##WORD embedding

# %% [markdown]
# ##Generating the vocabulary

# %%
import tensorflow as tf
import string
import io

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, Reshape, Lambda,TextVectorization
from tensorflow import keras
import keras.backend as K

# %%
# Now, create a custom standardization function to lowercase the text and
# remove punctuation.
def custom_standardization(input_data):
  lowercase = tf.strings.lower(input_data)
  return tf.strings.regex_replace(lowercase,
                                  '[%s]' % re.escape(string.punctuation), '')


# Define the vocabulary size and the number of words in a sequence.
vocab_size = 4096
sequence_length = 10

# Use the `TextVectorization` layer to normalize, split, and map strings to
# integers. Set the `output_sequence_length` length to pad all samples to the
# same length.
vectorize_layer = TextVectorization(
    standardize=custom_standardization,
    max_tokens=vocab_size,
    output_mode='int',
    output_sequence_length=sequence_length)

# %%
vectorize_layer.adapt(articles["content"])
vocab = vectorize_layer.get_vocabulary()

# %% [markdown]
# ##CBOW Implementation

# %%
from keras.preprocessing import sequence
from tensorflow.keras.utils import to_categorical
# Prepare the data for the CBOW model
def generate_data_cbow(corpus, window_size, V):
    all_in = []
    all_out = []

    # Iterate over all sentences
    for sentence in corpus:
        L = len(sentence)
        for index, word in enumerate(sentence):
            start = index - window_size
            end = index + window_size + 1

            # Empty list which will store the context words
            context_words = []
            for i in range(start, end):
                # Skip the 'same' word
                if i != index:
                    # Add a word as a context word if it is within the window size
                    if 0 <= i < L:
                        context_words.append(sentence[i])
                    else:
                        # Pad with zero if there are no words 
                        context_words.append(0)
            # Append the list with context words
            all_in.append(context_words)

            # Add one-hot encoding of the target word
            all_out.append(to_categorical(word, V))
                 
    return (np.array(all_in), np.array(all_out))

# %%
# Parameters
window_size = 2 
window_size_corpus = 4

# Set numpy seed for reproducible results
np.random.seed(42)
V = len(vocab)
corpus = tokenizer.texts_to_sequences(articles["content"])

# %%
# Create the training data
X_cbow, y_cbow = generate_data_cbow(corpus, window_size, V)
X_cbow.shape, y_cbow.shape
# Out:
# ((444, 4), (444, 238))

# %%
# Create the CBOW architecture
dims = [50, 150, 300]
cbow_models = []

for dim in dims:
    cbow = Sequential()

    # Add an Embedding layer
    cbow.add(Embedding(input_dim=V, 
                       output_dim=dim, 
                       input_length=window_size*2, # Note that we now have 2L words for each input entry
                       embeddings_initializer='glorot_uniform'))

    cbow.add(Lambda(lambda x: K.mean(x, axis=1), output_shape=(dim, )))

    cbow.add(Dense(V, activation='softmax', kernel_initializer='glorot_uniform'))

    cbow.compile(optimizer=keras.optimizers.Adam(),
                 loss='categorical_crossentropy',
                 metrics=['accuracy'])
    
    cbow.summary()
    print("")
    cbow_models.append(cbow)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 4, 50)             11900
#
#  lambda (Lambda)             (None, 50)                0
#
#  dense (Dense)               (None, 238)               12138
#
# =================================================================
# Total params: 24,038
# Trainable params: 24,038
# Non-trainable params: 0
# _________________________________________________________________
#
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 4, 150)            35700
#
#  lambda_1 (Lambda)           (None, 150)               0
#
#  dense_1 (Dense)             (None, 238)               35938
#
# =================================================================
# Total params: 71,638
# Trainable params: 71,638
# Non-trainable params: 0
# _________________________________________________________________
#
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 4, 300)            71400
#
#  lambda_2 (Lambda)           (None, 300)               0
#
#  dense_2 (Dense)             (None, 238)               71638
#
# =================================================================
# Total params: 143,038
# Trainable params: 143,038
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train CBOW model
for cbow in cbow_models:
    cbow.fit(X_cbow, y_cbow, batch_size=64, epochs=50, verbose=1)
    print("")
# Out:
# Epoch 1/50
# 7/7 [==============================] - 1s 4ms/step - loss: 5.4723 - accuracy: 0.0023
# Epoch 2/50
# 7/7 [==============================] - 0s 4ms/step - loss: 5.4596 - accuracy: 0.0225
# Epoch 3/50
# 7/7 [==============================] - 0s 4ms/step - loss: 5.4486 - accuracy: 0.0541
# Epoch 4/50
# 7/7 [==============================] - 0s 3ms/step - loss: 5.4374 - accuracy: 0.1036
# Epoch 5/50
# 7/7 [==============================] - 0s 3ms/step - loss: 5.4262 - accuracy: 0.1464
# Epoch 6/50
# 7/7 [==============================] - 0s 2ms/step - loss: 5.4146 - accuracy: 0.1869
# Epoch 7/50
# 7/7 [==============================] - 0s 3ms/step - loss: 5.4025 - accuracy: 0.2275
# Epoch 8/50
# 7/7 [==============================] - 0s 3ms/step - loss: 5.3901 - accuracy: 0.2387
# Epoch 9/50
# 7/7 [==============================] - 0s 3ms/step - loss: 5
# 7/7 [==============================] - 0s 5ms/step - loss: 2.3944 - accuracy: 0.6577
# Epoch 32/50
# 7/7 [==============================] - 0s 5ms/step - loss: 2.2638 - accuracy: 0.6712
# Epoch 33/50
# 7/7 [==============================] - 0s 6ms/step - loss: 2.1390 - accuracy: 0.6802
# Epoch 34/50
# 7/7 [==============================] - 0s 5ms/step - loss: 2.0209 - accuracy: 0.6937
# Epoch 35/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.9087 - accuracy: 0.7005
# Epoch 36/50
# 7/7 [==============================] - 0s 6ms/step - loss: 1.8029 - accuracy: 0.7275
# Epoch 37/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.7019 - accuracy: 0.7523
# Epoch 38/50
# 7/7 [==============================] - 0s 6ms/step - loss: 1.6071 - accuracy: 0.7635
# Epoch 39/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.5177 - accuracy: 0.7860
# Epoch 40/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.4339 - accuracy: 0.8063
# Epoch 41/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.3552 - accuracy: 0.8266
# Epoch 42/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.2798 - accuracy: 0.8468
# Epoch 43/50
# 7/7 [==============================] - 0s 6ms/step - loss: 1.2101 - accuracy: 0.8649
# Epoch 44/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.1443 - accuracy: 0.8829
# Epoch 45/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.0827 - accuracy: 0.9032
# Epoch 46/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.0248 - accuracy: 0.9077
# Epoch 47/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.9705 - accuracy: 0.9189
# Epoch 48/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.9196 - accuracy: 0.9347
# Epoch 49/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.8713 - accuracy: 0.9414
# Epoch 50/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.8270 - accuracy: 0.9505

# %% [markdown]
# Exporting the weigths of the best model

# %%
# Save embeddings for vectors of length 300 using cbow model
weights = cbow_models[2].get_weights()[0]

# %%
out_v = io.open('vectors.tsv', 'w', encoding='utf-8')
out_m = io.open('metadata.tsv', 'w', encoding='utf-8')

for index, word in enumerate(vocab):
  if index == 0:
    continue  # skip 0, it's padding.
  vec = weights[index]
  out_v.write('\t'.join([str(x) for x in vec]) + "\n")
  out_m.write(word + "\n")
out_v.close()
out_m.close()

# %%
try:
  from google.colab import files
  files.download('vectors.tsv')
  files.download('metadata.tsv')
except Exception:
  pass

# %% [markdown]
# ##Stroing the vocubulary and vectors in a dataframe

# %%
vocabulary = pd.DataFrame(weights, index = vocab)

# %%
def document_vector(doc):
    # remove out-of-vocabulary words
    doc = [word for word in doc.split(" ") if word in vocab]
    return np.mean(vocabulary.loc[doc], axis=0)

# %%
vectors = [document_vector(article) for article in articles["content"]]

# %%
#Generating the similarity between the articles using pairwise cosine similarity 
from sklearn.metrics.pairwise import cosine_similarity
similarities = cosine_similarity(vectors).astype('float64')

# %%
visualize_similarity(similarities)
# Out:
# <style type="text/css">
# #T_fcc05_row0_col0, #T_fcc05_row1_col1, #T_fcc05_row2_col2, #T_fcc05_row3_col3, #T_fcc05_row4_col4, #T_fcc05_row5_col5, #T_fcc05_row6_col6 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_fcc05_row0_col1, #T_fcc05_row1_col0, #T_fcc05_row3_col6, #T_fcc05_row6_col3 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_fcc05_row0_col2, #T_fcc05_row2_col0 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_fcc05_row0_col3, #T_fcc05_row3_col0 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_fcc05_row0_col4, #T_fcc05_row4_col0 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_fcc05_row0_col5, #T_fcc05_row5_col0 {
#   background-color: #03456c;
#   color: #f1f1f1;
# }
# #T_fcc05_row0_col6, #T_fcc05_row6_col0 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_fcc05_row1_col2, #T_fcc05_row2_col1, #T_fcc05_row3_col5, #T_fcc05_row5_col3 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_fcc05_row1_col3, #T_fcc05_row3_col1 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_fcc05_row1_col4, #T_fcc05_row4_col1 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_fcc05_row1_col5, #T_fcc05_row5_col1 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_fcc05_row1_col6, #T_fcc05_row6_col1 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_fcc05_row2_col3, #T_fcc05_row3_col2 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_fcc05_row2_col4, #T_fcc05_row4_col2 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_fcc05_row2_col5, #T_fcc05_row5_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_fcc05_row2_col6, #T_fcc05_row6_col2 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_fcc05_row3_col4, #T_fcc05_row4_col3 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_fcc05_row4_col5, #T_fcc05_row5_col4 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_fcc05_row4_col6, #T_fcc05_row6_col4 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_fcc05_row5_col6, #T_fcc05_row6_col5 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fcc05_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >title</th>
#       <th class="col_heading level0 col0" >Bio gas</th>
#       <th class="col_heading level0 col1" >Natural language processing (NLP) </th>
#       <th class="col_heading level0 col2" >Web Development</th>
#       <th class="col_heading level0 col3" >process scheduling</th>
#       <th class="col_heading level0 col4" >Hybrid Vechicle </th>
#       <th class="col_heading level0 col5" >Gobar Gas</th>
#       <th class="col_heading level0 col6" >Artificial Intelligence</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >title</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fcc05_level0_row0" class="row_heading level0 row0" >Bio gas</th>
#       <td id="T_fcc05_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_fcc05_row0_col1" class="data row0 col1" >0.156995</td>
#       <td id="T_fcc05_row0_col2" class="data row0 col2" >-0.142720</td>
#       <td id="T_fcc05_row0_col3" class="data row0 col3" >-0.051127</td>
#       <td id="T_fcc05_row0_col4" class="data row0 col4" >0.242414</td>
#       <td id="T_fcc05_row0_col5" class="data row0 col5" >0.942099</td>
#       <td id="T_fcc05_row0_col6" class="data row0 col6" >0.298123</td>
#     </tr>
#     <tr>
#       <th id="T_fcc05_level0_row1" class="row_heading level0 row1" >Natural language processing (NLP) </th>
#       <td id="T_fcc05_row1_col0" class="data row1 col0" >0.156995</td>
#       <td id="T_fcc05_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_fcc05_row1_col2" class="data row1 col2" >-0.044690</td>
#       <td id="T_fcc05_row1_col3" class="data row1 col3" >-0.030622</td>
#       <td id="T_fcc05_row1_col4" class="data row1 col4" >0.194836</td>
#       <td id="T_fcc05_row1_col5" class="data row1 col5" >0.213690</td>
#       <td id="T_fcc05_row1_col6" class="data row1 col6" >0.463299</td>
#     </tr>
#     <tr>
#       <th id="T_fcc05_level0_row2" class="row_heading level0 row2" >Web Development</th>
#       <td id="T_fcc05_row2_col0" class="data row2 col0" >-0.142720</td>
#       <td id="T_fcc05_row2_col1" class="data row2 col1" >-0.044690</td>
#       <td id="T_fcc05_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_fcc05_row2_col3" class="data row2 col3" >0.022613</td>
#       <td id="T_fcc05_row2_col4" class="data row2 col4" >0.019174</td>
#       <td id="T_fcc05_row2_col5" class="data row2 col5" >-0.209064</td>
#       <td id="T_fcc05_row2_col6" class="data row2 col6" >-0.010305</td>
#     </tr>
#     <tr>
#       <th id="T_fcc05_level0_row3" class="row_heading level0 row3" >process scheduling</th>
#       <td id="T_fcc05_row3_col0" class="data row3 col0" >-0.051127</td>
#       <td id="T_fcc05_row3_col1" class="data row3 col1" >-0.030622</td>
#       <td id="T_fcc05_row3_col2" class="data row3 col2" >0.022613</td>
#       <td id="T_fcc05_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_fcc05_row3_col4" class="data row3 col4" >0.010521</td>
#       <td id="T_fcc05_row3_col5" class="data row3 col5" >-0.047312</td>
#       <td id="T_fcc05_row3_col6" class="data row3 col6" >0.156891</td>
#     </tr>
#     <tr>
#       <th id="T_fcc05_level0_row4" class="row_heading level0 row4" >Hybrid Vechicle </th>
#       <td id="T_fcc05_row4_col0" class="data row4 col0" >0.242414</td>
#       <td id="T_fcc05_row4_col1" class="data row4 col1" >0.194836</td>
#       <td id="T_fcc05_row4_col2" class="data row4 col2" >0.019174</td>
#       <td id="T_fcc05_row4_col3" class="data row4 col3" >0.010521</td>
#       <td id="T_fcc05_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_fcc05_row4_col5" class="data row4 col5" >0.251481</td>
#       <td id="T_fcc05_row4_col6" class="data row4 col6" >0.160158</td>
#     </tr>
#     <tr>
#       <th id="T_fcc05_level0_row5" class="row_heading level0 row5" >Gobar Gas</th>
#       <td id="T_fcc05_row5_col0" class="data row5 col0" >0.942099</td>
#       <td id="T_fcc05_row5_col1" class="data row5 col1" >0.213690</td>
#       <td id="T_fcc05_row5_col2" class="data row5 col2" >-0.209064</td>
#       <td id="T_fcc05_row5_col3" class="data row5 col3" >-0.047312</td>
#       <td id="T_fcc05_row5_col4" class="data row5 col4" >0.251481</td>
#       <td id="T_fcc05_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_fcc05_row5_col6" class="data row5 col6" >0.346066</td>
#     </tr>
#     <tr>
#       <th id="T_fcc05_level0_row6" class="row_heading level0 row6" >Artificial Intelligence</th>
#       <td id="T_fcc05_row6_col0" class="data row6 col0" >0.298123</td>
#       <td id="T_fcc05_row6_col1" class="data row6 col1" >0.463299</td>
#       <td id="T_fcc05_row6_col2" class="data row6 col2" >-0.010305</td>
#       <td id="T_fcc05_row6_col3" class="data row6 col3" >0.156891</td>
#       <td id="T_fcc05_row6_col4" class="data row6 col4" >0.160158</td>
#       <td id="T_fcc05_row6_col5" class="data row6 col5" >0.346066</td>
#       <td id="T_fcc05_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
threshold_value = 0.4
#adding the similarity to the dataframe
add_similarity(similarities)
articles.head()
# Out:
#                                 title                    id  \
# 0                             Bio gas  G2q76a8fpjzXg3PAaGLi
# 1  Natural language processing (NLP)   L1oTvamoCndM7wLYvQ4S
# 2                     Web Development  MAVau2RZpWtDwC9YkpoH
# 3                  process scheduling  Y4RYcntx6PUpP9uMAoBZ
# 4                    Hybrid Vechicle   aT99AvBvVW43U1bEXn9p
#
#                                              content              similar_id  \
# 0  biogas mixture gases primarily consisting meth...  [jDDngynd6QLl44LRO9BB]
# 1  natural language processing nlp refers branch ...  [mxRSMBi9Upvrx2L4oMSs]
# 2  web development work involved developing websi...                      []
# 3  process scheduling activity process manager ha...                      []
# 4  hybrid electric vehicles powered internal comb...                      []
#
#   similar_per
# 0     [0.942]
# 1     [0.463]
# 2          []
# 3          []
# 4          []

# %%
#Best of all the three methods is CBOW implementation with custom neural network based word embeddings

# %% [markdown]
# ##adding the similarity to the dataframe articles

# %%
add_similarity(similarities)

# %% [markdown]
# ##Updating the top 3 related artocles to the article

# %%
update_article_similarity()
